# %% [markdown]
# # Solutions to Exercises in Data Analysis and Statistics

# %% [markdown]
# ### Exercise: Data visualization

# %% [markdown]
# ### Part a)

# %%
dat <- read.csv("speed_gender_height.csv")
attach(dat)

boxplot(speed ~ gender, ylab="speed")
# Out:
# plot without title

# %% [markdown]
# ### Part b)
# Here , we use different plotting symbols to distinguish between males and females.

# %%
plot(height, speed, pch=as.integer(gender))
legend("bottomright", levels(gender), pch=gender)
# Out:
# plot without title
